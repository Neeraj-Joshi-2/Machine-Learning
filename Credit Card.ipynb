# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error,accuracy_score
from sklearn.metrics import classification_report

# %%
data = pd.read_csv('UCI_Credit_Card.csv')
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
x = data.drop(columns = ['ID' , 'SEX' , 'MARRIAGE' , 'default.payment.next.month'])
y = data['default.payment.next.month']

# %%
x
# Out:
#        LIMIT_BAL  EDUCATION  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# 0        20000.0          2   24      2      2     -1     -1     -2     -2
# 1       120000.0          2   26     -1      2      0      0      0      2
# 2        90000.0          2   34      0      0      0      0      0      0
# 3        50000.0          2   37      0      0      0      0      0      0
# 4        50000.0          2   57     -1      0     -1      0      0      0
# ...          ...        ...  ...    ...    ...    ...    ...    ...    ...
# 29995   220000.0          3   39      0      0      0      0      0      0
# 29996   150000.0          3   43     -1     -1     -1     -1      0      0
# 29997    30000.0          2   37      4      3      2     -1      0      0
# 29998    80000.0          3   41      1     -1      0      0      0     -1
# 29999    50000.0          2   46      0      0      0      0      0      0
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y , test_size = 0.25)

print('Shape(X_train) : ' , x_train.shape)
print('Shape(y_train) : ' , y_train.shape)
print('Shape(X_test) : ' , x_test .shape)
print('Shape(y_test) : ' , y_test.shape)
# Out:
# Shape(X_train) :  (22500, 21)
# Shape(y_train) :  (22500,)
# Shape(X_test) :  (7500, 21)
# Shape(y_test) :  (7500,)

# %% [markdown]
# # RandomForestClassifier

# %%
clf = RandomForestClassifier()

# %%
clf.fit(x_train , y_train)

pred = clf.predict(x_test)

print(pred)

score = clf.score(x_train , y_train)
print('Accuracy : ' , score*100)

score = clf.score(x_test , y_test)
print('Accuracy : ' , score*100)
# Out:
# [1 0 0 ... 0 0 0]
# Accuracy :  99.86222222222221
# Accuracy :  81.89333333333333

# %%
print('Parameters currently in use:\n')
print(clf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# ### Classification Report

# %%
rep = classification_report(y_test , pred)
print(rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.88      5812
#            1       0.64      0.37      0.47      1688
#
#     accuracy                           0.81      7500
#    macro avg       0.74      0.66      0.68      7500
# weighted avg       0.79      0.81      0.79      7500

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cf = confusion_matrix(y_test , pred)

# %%
cf
# Out:
# array([[5451,  361],
#        [1057,  631]], dtype=int64)

# %% [markdown]
# ### HyperParameter Tunning

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {

    'n_estimators': [10 , 20 , 30],
    'max_depth': [15 , 20 , 30 , 50],
    'criterion': ['gini' , 'entropy']
    
}

# %%
rc = RandomForestClassifier(random_state = 0)

grid = GridSearchCV(estimator = rc , param_grid = param_grid , cv = 3 , scoring = 'accuracy')

grid.fit(x_train , y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=0,
# ...

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 15, 'n_estimators': 20}

# %%
print('Accuracy : ' + str(grid.best_score_))
# Out:
# Accuracy : 0.8176888888888888

# %% [markdown]
# ### RandomSearch

# %%
from scipy.stats import randint as sp_rand
from random import randrange as r_rand
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid = {

    'n_estimators': sp_rand(10 , 100),
    'max_depth': sp_rand(5 , 10),
    'criterion': ['gini' , 'entropy']
    
}

n_itr_search = 20

# %%
rc = RandomForestClassifier(random_state = 0)

random = RandomizedSearchCV(rc , param_distributions = param_grid , n_iter = n_itr_search , cv = 3 , scoring = 'accuracy')

random.fit(x_train , y_train)
# Out:
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
# ...

# %%
print(random.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 7, 'n_estimators': 40}

# %%
print('Accuracy : ' + str(random.best_score_))
# Out:
# Accuracy : 0.8220444444444445
