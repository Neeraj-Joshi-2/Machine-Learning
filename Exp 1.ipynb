# %% [markdown]
# # Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(df.sepal_length,df.sepal_width)
plt.xlabel('SEPAL LENGTH')
plt.ylabel('SEPAL WIDTH')
plt.title('PLOT')
# Out:
# Text(0.5, 1.0, 'PLOT')

# %%
plt.scatter(df.sepal_length,df.sepal_width)
ax = plt.gca()
ax.axis([3,10,2,5])
# Out:
# [3, 10, 2, 5]

# %%
plt.scatter(df.sepal_length,df.sepal_width)
plt.scatter(df.petal_length,df.petal_width)

# %%
colors = ['green']*(len(df)-1)
colors.append('red')

plt.figure()
plt.scatter(df.petal_length,df.petal_width,c=colors)

# %% [markdown]
# # Barchart

# %%
plt.bar(df.petal_length,df.petal_width,width=0.3, color='r')
# Out:
# <BarContainer object of 150 artists>

# %%
plt.barh(df.petal_length,df.petal_width,color='b')
# Out:
# <BarContainer object of 150 artists>

# %%
plt.figure(figsize=(10,5))
plt.bar(df.petal_length,df.petal_width,color='cyan',label='label1')
plt.bar(df.sepal_length,df.sepal_width,color='magenta',label='label2')
plt.legend()

# %% [markdown]
# # Histogram (matplotlib)

# %%
plt.hist(df.sepal_length)
plt.title('HISTOGRAM PLOT' , fontsize = 15)
plt.xlabel('MID VALUE RANGE' , fontsize = 15)
plt.ylabel('FREQUENCY' , fontsize = 15)
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
plt.hist(df.sepal_length , bins = 20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # SEABORN

# %%
df = pd.read_csv('Rainfalldataset.csv')
df
# Out:
#       temp(c)  pressure(mb)  humidity()  cloud cover()  wind speed(mph)  \
# 0          28          1005        85.0             22                7
# 1          27          1005        83.0             15                6
# 2          28          1006        80.0             15                5
# 3          33          1007        70.0             16                6
# 4          35          1006        61.0             32                7
# ...       ...           ...         ...            ...              ...
# 3951       36          1002        56.0             26                5
# 3952       38          1001        48.0             51                4
# 3953       38           999        50.0             75                3
# 3954       38          1000        58.0             62                3
# 3955       35          1001        64.0             68                5
#
#       wind dir.  precip.(mm)
# 0             6          0.1
# 1             7          0.0
# ...

# %%
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.scatterplot(x = df['temp(c)'] , y = df['pressure(mb)'] , marker = '+' , color = 'magenta')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x = 'temp(c)' , y = 'pressure(mb)' , data = df , hue = 'temp(c)')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x = 'temp(c)' , y = 'pressure(mb)' , data = df , hue = 'temp(c)' , size = 'temp(c)')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(df['temp(c)'] , color = 'blue')

# %%
sns.jointplot(df['temp(c)'] , df['pressure(mb)'] , alpha=0.4)

# %%
sns.jointplot(df['temp(c)'] , df['pressure(mb)'] , kind='hex')

# %%
sns.set_style('white')
sns.jointplot(df['temp(c)'] , df['pressure(mb)'] , kind='kde', space=0)

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris, hue='species', diag_kind='kde')

# %%
plt.figure(figsize=(12,8))
plt.subplot(121)
sns.swarmplot('species', 'petal_length', data=iris);
plt.subplot(122)
sns.violinplot('species', 'petal_length', data=iris);

# %% [markdown]
# # Subplot

# %%
df = pd.read_csv('iris.csv')
plt.figure()
plt.plot(df['sepal_length'], '-o',c='cyan')

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3, 3, 
                                                            sharex = True,
                                                            sharey = True
                                                            )
ax5.plot(df['sepal_length'], '-')

# %% [markdown]
# # Heatmaps

# %%
plt.figure()

Y = df.sepal_length
X = df.sepal_width

_ = plt.hist2d(X, Y, bins=10)

# %%
plt.figure()
_ = plt.hist2d(X, Y, bins=100)

# %% [markdown]
# # Box and Whisker Plot

# %%
plt.figure()
_ = plt.boxplot(df['petal_length'], whis='range')

# %%
plt.figure()
_ = plt.boxplot(df['sepal_length'], whis='range')

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['sepal_length'],df['petal_length'] , df['sepal_width']], whis='range')
ax2 = mpl_il.inset_axes(plt.gca(), width='60%', height='40%', loc=2)
ax2.hist(df['sepal_width'], bins=100)
ax2.margins(x=0.5)

# %%
plt.figure()
_ = plt.boxplot([df['sepal_length'],df['petal_length'] , df['sepal_width'] , df['petal_width']])

# %% [markdown]
# # Plotting with Pandas

# %%
plt.style.use('seaborn-colorblind')

# %%
df = pd.read_csv('iris.csv')
df.plot()

# %%
df.plot('sepal_length', 'sepal_width', kind='scatter');

# %%
df.plot.scatter('sepal_length', 'sepal_width', c='sepal_width', s=df['sepal_width'], colormap='viridis')

# %%
df.plot.box()

# %%
df.plot.hist(alpha=0.7)

# %%
df.plot.kde()
